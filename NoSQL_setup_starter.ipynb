# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Part 1: Database and Jupyter Notebook Set Up

# %% [markdown]
# Import the data provided in the `establishments.json` file from your Terminal. Name the database `uk_food` and the collection `establishments`.
#
# Within this markdown cell, copy the line of text you used to import the data from your Terminal. This way, future analysts will be able to repeat your process.
#
# e.g.: Import the dataset with mongoimport --db uk_food --collection establishments --file establishments.json --jsonArray

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# confirm that our new database was created
print(mongo.list_database_names())
# Out:
# ['admin', 'classDB', 'config', 'local', 'uk_food']

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our new database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# review a document in the establishments collection
establishment = db.establishments.find_one()
pprint(establishment)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66f4c73105f93afc7c6a46e3'),
#  'geocode': {'latitude': 51.490142, 'longitude': 0.08384},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 2: Update the Database

# %% [markdown]
# 1. An exciting new halal restaurant just opened in Greenwich, but hasn't been rated yet. The magazine has asked you to include it in your analysis. Add the following restaurant "Penang Flavours" to the database.

# %%
# Create a dictionary for the new restaurant data
new_restaurant = {
    "BusinessName": "Penang Flavours",
    "BusinessType": "Restaurant/Cafe/Canteen",
    "BusinessTypeID": "",
    "AddressLine1": "Penang Flavours",
    "AddressLine2": "146A Plumstead Rd",
    "AddressLine3": "London",
    "AddressLine4": "",
    "PostCode": "SE18 7DY",
    "Phone": "",
    "LocalAuthorityCode": "511",
    "LocalAuthorityName": "Greenwich",
    "LocalAuthorityWebSite": "http://www.royalgreenwich.gov.uk",
    "LocalAuthorityEmailAddress": "health@royalgreenwich.gov.uk",
    "scores": {
        "Hygiene": "",
        "Structural": "",
        "ConfidenceInManagement": ""
    },
    "SchemeType": "FHRS",
    "geocode": {
        "longitude": "0.08384000",
        "latitude": "51.49014200"
    },
    "RightToReply": "",
    "Distance": 4623.9723280747176,
    "NewRatingPending": True
}

# Print the new restaurant dictionary
pprint(new_restaurant)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': '',
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %%
# Insert the new restaurant into the collection
db.establishments.insert_one(new_restaurant)
# Out:
# InsertOneResult(ObjectId('66ff389c8e6bfde5a9485d33'), acknowledged=True)

# %%
# Check that the new restaurant was inserted
business = db.establishments.find_one(
    {"BusinessType": "Restaurant/Cafe/Canteen"},
    {"BusinessTypeID": 1, "BusinessType": 1, "_id": 0}
)
pprint(business)
# Out:
# {'BusinessType': 'Restaurant/Cafe/Canteen', 'BusinessTypeID': 1}

# %% [markdown]
# 2. Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the `BusinessTypeID` and `BusinessType` fields.

# %%
# Find the BusinessTypeID for "Restaurant/Cafe/Canteen" and return only the BusinessTypeID and BusinessType fields
business_type_id = business['BusinessTypeID']
business_type_id
# Out:
# 1

# %% [markdown]
# 3. Update the new restaurant with the `BusinessTypeID` you found.

# %%
# Update the new restaurant with the correct BusinessTypeID
db.establishments.update_one(
    {"BusinessName": "Penang Flavours"},
    {"$set": {"BusinessTypeID": business_type_id}}
)
# Out:
# UpdateResult({'n': 1, 'nModified': 0, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Confirm that the new restaurant was updated
updated_restaurant = db.establishments.find_one({"BusinessName": "Penang Flavours"})
pprint(updated_restaurant)
# Out:
# {'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'Distance': 4623.972328074718,
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': True,
#  'Phone': '',
#  'PostCode': 'SE18 7DY',
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('66f4c73105f93afc7c6a46e3'),
#  'geocode': {'latitude': 51.490142, 'longitude': 0.08384},
#  'scores': {'ConfidenceInManagement': '', 'Hygiene': '', 'Structural': ''}}

# %% [markdown]
# 4. The magazine is not interested in any establishments in Dover, so check how many documents contain the Dover Local Authority. Then, remove any establishments within the Dover Local Authority from the database, and check the number of documents to ensure they were deleted.

# %%
# Find how many documents have LocalAuthorityName as "Dover"
dover_count = db.establishments.count_documents({"LocalAuthorityName": "Dover"})
dover_count
# Out:
# 1988

# %%
# Delete all documents where LocalAuthorityName is "Dover"
delete = db.establishments.delete_many({"LocalAuthorityName": "Dover"})
delete
# Out:
# DeleteResult({'n': 1988, 'ok': 1.0}, acknowledged=True)

# %%
# Check if any remaining documents include Dover
dover = db.establishments.find_one({"LocalAuthorityName": "Dover"})
if dover:
    print("There are still documents with 'Dover'.")
else:
    print("No documents with 'Dover' remain.")
# Out:
# No documents with 'Dover' remain.

# %%
# Check that other documents remain with 'find_one'
establishments.find_one()
# Out:
# {'_id': ObjectId('66f4c73105f93afc7c6a46e3'),
#  'BusinessName': 'Penang Flavours',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'Penang Flavours',
#  'AddressLine2': '146A Plumstead Rd',
#  'AddressLine3': 'London',
#  'AddressLine4': '',
#  'PostCode': 'SE18 7DY',
#  'Phone': '',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'scores': {'Hygiene': '', 'Structural': '', 'ConfidenceInManagement': ''},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 0.08384, 'latitude': 51.490142},
#  'RightToReply': '',
#  'Distance': 4623.972328074718,
#  'NewRatingPending': True}

# %% [markdown]
# 5. Some of the number values are stored as strings, when they should be stored as numbers.

# %% [markdown]
# Use `update_many` to convert `latitude` and `longitude` to decimal numbers.

# %%
# Change the data type from String to Decimal for longitude and latitude
db.establishments.update_many({"geocode.longitude": {"$type": "string"},"geocode.latitude": {"$type": "string"}},
    [{"$set": {"geocode.longitude": {"$toDecimal": "$geocode.longitude"},"geocode.latitude": {"$toDecimal": "$geocode.latitude"}}}])
# Out:
# UpdateResult({'n': 77571, 'nModified': 77571, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %% [markdown]
# Use `update_many` to convert `RatingValue` to integer numbers.

# %%
# Set non 1-5 Rating Values to Null
non_ratings = ["AwaitingInspection", "Awaiting Inspection", "AwaitingPublication", "Pass", "Exempt"]
establishments.update_many({"RatingValue": {"$in": non_ratings}}, [ {'$set':{ "RatingValue" : None}} ])
# Out:
# UpdateResult({'n': 8182, 'nModified': 8182, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Change the data type from String to Integer for RatingValue
db.establishments.update_many({"RatingValue": {"$type": "string"}},
    [{"$set": {"RatingValue": {"$toInt": "$RatingValue"}}}])
# Out:
# UpdateResult({'n': 69388, 'nModified': 69388, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
# Check that the coordinates and rating value are now numbers
[doc for doc in establishments.find({}, ['geocode.longtidude', 'geocode.latitude'])]
# Out:
# [{'_id': ObjectId('66f4c73105f93afc7c6a46e3'),
#   'geocode': {'latitude': 51.490142}},
#  {'_id': ObjectId('66fdf06da927889fa9c9ab8b'),
#   'geocode': {'latitude': 51.490142}},
#  {'_id': ObjectId('66fdf107a927889fa9c9ab8c'),
#   'geocode': {'latitude': 51.490142}},
#  {'_id': ObjectId('66fdf2b773f27011595f86be'),
#   'geocode': {'latitude': Decimal128('51.49014200')}},
#  {'_id': ObjectId('66fdf32973f27011595f86c0'),
#   'geocode': {'latitude': Decimal128('51.49014200')}},
#  {'_id': ObjectId('66fdf3bb73f27011595f86c2'),
#   'geocode': {'latitude': Decimal128('51.49014200')}},
#  {'_id': ObjectId('66fdf45a73f27011595f86c4'),
#   'geocode': {'latitude': Decimal128('51.49014200')}},
#  {'_id': ObjectId('66fe07b27327f32a5bafe756'),
#   'geocode': {'latitude': Decimal128('51.49014200')}},
#  {'_id': ObjectId('66feeb1c544146aa4d6e5a5b'),
#   'geocode': {'latitude': Decimal128('51.49014200')}},
#  {'_id': ObjectId('66feef1bf54c20c047b6ed33'),
#   'geocode': {'latitude': Decimal128('51.49014200')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0d8'),
#   'geocode': {'latitude': Decimal128('51.08084')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0d9'),
#   'geocode': {'latitude': Decimal128('51.08084')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0da'),
#   'geocode': {'latitude': Decimal128('51.086058')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0dc'),
#   'geocode': {'latitude': Decimal128('51.08084')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0dd'),
#   'geocode': {'latitude': Decimal128('51.085797')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0de'),
#   'geocode': {'latitude': Decimal128('51.083812')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0df'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0e0'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0e1'),
#   'geocode': {'latitude': Decimal128('51.08084')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0e2'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0e3'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0e4'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0e5'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0e6'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0e7'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0e8'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0e9'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0ea'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0eb'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0ec'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0ed'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0ee'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0ef'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0f0'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0f1'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0f2'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0f3'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0f4'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0f5'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0f6'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0f7'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0f8'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0f9'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0fa'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0fb'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0fc'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0fd'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0fe'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a0ff'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a100'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a101'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a102'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a103'),
#   'geocode': {'latitude': Decimal128('51.0783519967076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a104'),
#   'geocode': {'latitude': Decimal128('51.0805695006979')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a106'),
#   'geocode': {'latitude': Decimal128('51.078449')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a107'),
#   'geocode': {'latitude': Decimal128('51.095015')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a108'),
#   'geocode': {'latitude': Decimal128('51.080673')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a109'),
#   'geocode': {'latitude': Decimal128('51.080446')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a10a'),
#   'geocode': {'latitude': Decimal128('51.079985650005')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a10b'),
#   'geocode': {'latitude': Decimal128('51.080284')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a10c'),
#   'geocode': {'latitude': Decimal128('51.080284')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a10f'),
#   'geocode': {'latitude': Decimal128('51.087887')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a110'),
#   'geocode': {'latitude': Decimal128('51.079613')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a111'),
#   'geocode': {'latitude': Decimal128('51.077971')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a112'),
#   'geocode': {'latitude': Decimal128('51.079613')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a113'),
#   'geocode': {'latitude': Decimal128('51.083232')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a115'),
#   'geocode': {'latitude': Decimal128('51.080224')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a116'),
#   'geocode': {'latitude': Decimal128('51.080838')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a117'),
#   'geocode': {'latitude': Decimal128('51.081735')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a118'),
#   'geocode': {'latitude': Decimal128('51.081546')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a119'),
#   'geocode': {'latitude': Decimal128('51.07915')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a11a'),
#   'geocode': {'latitude': Decimal128('51.07915')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a11c'),
#   'geocode': {'latitude': Decimal128('51.0803')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a11e'),
#   'geocode': {'latitude': Decimal128('51.086262')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a120'),
#   'geocode': {'latitude': Decimal128('51.0818061828613')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a121'),
#   'geocode': {'latitude': Decimal128('51.0877821')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a123'),
#   'geocode': {'latitude': Decimal128('51.0804748535156')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a124'),
#   'geocode': {'latitude': Decimal128('51.0804824829102')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a125'),
#   'geocode': {'latitude': Decimal128('51.0804824829102')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a126'),
#   'geocode': {'latitude': Decimal128('51.0793')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a127'),
#   'geocode': {'latitude': Decimal128('51.079301')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a128'),
#   'geocode': {'latitude': Decimal128('51.080956')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a129'),
#   'geocode': {'latitude': Decimal128('51.0809478759766')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a12a'),
#   'geocode': {'latitude': Decimal128('51.080956')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a12b'),
#   'geocode': {'latitude': Decimal128('51.080956')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a12c'),
#   'geocode': {'latitude': Decimal128('51.080956')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a12d'),
#   'geocode': {'latitude': Decimal128('51.0917365039471')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a12e'),
#   'geocode': {'latitude': Decimal128('51.097794')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a12f'),
#   'geocode': {'latitude': Decimal128('51.080805')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a130'),
#   'geocode': {'latitude': Decimal128('51.080804')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a131'),
#   'geocode': {'latitude': Decimal128('51.079905')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a132'),
#   'geocode': {'latitude': Decimal128('51.0810258')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a133'),
#   'geocode': {'latitude': Decimal128('51.080339')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a134'),
#   'geocode': {'latitude': Decimal128('51.080339')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a135'),
#   'geocode': {'latitude': Decimal128('51.08034')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a136'),
#   'geocode': {'latitude': Decimal128('51.08034')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a137'),
#   'geocode': {'latitude': Decimal128('51.08034')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a138'),
#   'geocode': {'latitude': Decimal128('51.08034')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a13a'),
#   'geocode': {'latitude': Decimal128('51.0802956')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a13b'),
#   'geocode': {'latitude': Decimal128('51.079889')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a13c'),
#   'geocode': {'latitude': Decimal128('51.079532623291')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a13d'),
#   'geocode': {'latitude': Decimal128('51.0803409')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a13e'),
#   'geocode': {'latitude': Decimal128('51.079542')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a13f'),
#   'geocode': {'latitude': Decimal128('51.079542')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a140'),
#   'geocode': {'latitude': Decimal128('51.079542')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a141'),
#   'geocode': {'latitude': Decimal128('51.0797886')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a142'),
#   'geocode': {'latitude': Decimal128('51.078209')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a143'),
#   'geocode': {'latitude': Decimal128('51.0798931')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a144'),
#   'geocode': {'latitude': Decimal128('51.0798')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a145'),
#   'geocode': {'latitude': Decimal128('51.079799')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a146'),
#   'geocode': {'latitude': Decimal128('51.080412')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a147'),
#   'geocode': {'latitude': Decimal128('51.0802346')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a148'),
#   'geocode': {'latitude': Decimal128('51.089491')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a149'),
#   'geocode': {'latitude': Decimal128('51.080412')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a14a'),
#   'geocode': {'latitude': Decimal128('51.0800235')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a14b'),
#   'geocode': {'latitude': Decimal128('51.089491')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a14c'),
#   'geocode': {'latitude': Decimal128('51.080675')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a14d'),
#   'geocode': {'latitude': Decimal128('51.0806732177734')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a14e'),
#   'geocode': {'latitude': Decimal128('51.0806941')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a14f'),
#   'geocode': {'latitude': Decimal128('51.0793698')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a150'),
#   'geocode': {'latitude': Decimal128('51.082322')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a151'),
#   'geocode': {'latitude': Decimal128('51.08164')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a152'),
#   'geocode': {'latitude': Decimal128('51.07954')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a153'),
#   'geocode': {'latitude': Decimal128('51.083976')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a154'),
#   'geocode': {'latitude': Decimal128('51.07954')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a155'),
#   'geocode': {'latitude': Decimal128('51.08164')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a156'),
#   'geocode': {'latitude': Decimal128('51.07954')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a157'),
#   'geocode': {'latitude': Decimal128('51.07954')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a158'),
#   'geocode': {'latitude': Decimal128('51.08472')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a159'),
#   'geocode': {'latitude': Decimal128('51.0816612')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a15a'),
#   'geocode': {'latitude': Decimal128('51.084721')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a15b'),
#   'geocode': {'latitude': Decimal128('51.0804176330566')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a15c'),
#   'geocode': {'latitude': Decimal128('51.080417')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a15d'),
#   'geocode': {'latitude': Decimal128('51.080181')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a15e'),
#   'geocode': {'latitude': Decimal128('51.08187')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a15f'),
#   'geocode': {'latitude': Decimal128('51.078296')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a160'),
#   'geocode': {'latitude': Decimal128('51.078296')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a161'),
#   'geocode': {'latitude': Decimal128('51.078296')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a162'),
#   'geocode': {'latitude': Decimal128('51.078296')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a163'),
#   'geocode': {'latitude': Decimal128('51.08187')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a164'),
#   'geocode': {'latitude': Decimal128('51.081494')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a165'),
#   'geocode': {'latitude': Decimal128('51.080675')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a166'),
#   'geocode': {'latitude': Decimal128('51.080417')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a167'),
#   'geocode': {'latitude': Decimal128('51.080675')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a168'),
#   'geocode': {'latitude': Decimal128('51.08187')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a169'),
#   'geocode': {'latitude': Decimal128('51.080675')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a16a'),
#   'geocode': {'latitude': Decimal128('51.080675')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a16b'),
#   'geocode': {'latitude': Decimal128('51.085454')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a16c'),
#   'geocode': {'latitude': Decimal128('51.086189')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a16d'),
#   'geocode': {'latitude': Decimal128('51.080675')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a16e'),
#   'geocode': {'latitude': Decimal128('51.0818634033203')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a16f'),
#   'geocode': {'latitude': Decimal128('51.0785865783691')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a170'),
#   'geocode': {'latitude': Decimal128('51.078587')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a171'),
#   'geocode': {'latitude': Decimal128('51.0798709')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a172'),
#   'geocode': {'latitude': Decimal128('51.0780695')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a173'),
#   'geocode': {'latitude': Decimal128('51.0802287')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a174'),
#   'geocode': {'latitude': Decimal128('51.086189')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a175'),
#   'geocode': {'latitude': Decimal128('51.0781968')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a176'),
#   'geocode': {'latitude': Decimal128('51.078117')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a177'),
#   'geocode': {'latitude': Decimal128('51.079632')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a178'),
#   'geocode': {'latitude': Decimal128('51.079632')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a179'),
#   'geocode': {'latitude': Decimal128('51.083569')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a17a'),
#   'geocode': {'latitude': Decimal128('51.0781968')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a17b'),
#   'geocode': {'latitude': Decimal128('51.083569')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a17c'),
#   'geocode': {'latitude': Decimal128('51.080315')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a17d'),
#   'geocode': {'latitude': Decimal128('51.078131')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a17e'),
#   'geocode': {'latitude': Decimal128('51.0818613')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a17f'),
#   'geocode': {'latitude': Decimal128('51.0818613')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a181'),
#   'geocode': {'latitude': Decimal128('51.080315')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a182'),
#   'geocode': {'latitude': Decimal128('51.080211')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a183'),
#   'geocode': {'latitude': Decimal128('51.080211')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a184'),
#   'geocode': {'latitude': Decimal128('51.080211')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a186'),
#   'geocode': {'latitude': Decimal128('51.080217')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a187'),
#   'geocode': {'latitude': Decimal128('51.079161')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a188'),
#   'geocode': {'latitude': Decimal128('51.079481')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a189'),
#   'geocode': {'latitude': Decimal128('51.079482')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a18a'),
#   'geocode': {'latitude': Decimal128('51.079482')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a18b'),
#   'geocode': {'latitude': Decimal128('51.081337')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a18c'),
#   'geocode': {'latitude': Decimal128('51.081337')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a18d'),
#   'geocode': {'latitude': Decimal128('51.0783483')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a18e'),
#   'geocode': {'latitude': Decimal128('51.0783433')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a18f'),
#   'geocode': {'latitude': Decimal128('51.088735')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a190'),
#   'geocode': {'latitude': Decimal128('51.078317')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a191'),
#   'geocode': {'latitude': Decimal128('51.081526')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a192'),
#   'geocode': {'latitude': Decimal128('51.0824157')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a193'),
#   'geocode': {'latitude': Decimal128('51.082867')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a194'),
#   'geocode': {'latitude': Decimal128('51.078317')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a195'),
#   'geocode': {'latitude': Decimal128('51.078317')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a197'),
#   'geocode': {'latitude': Decimal128('51.087132')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a198'),
#   'geocode': {'latitude': Decimal128('51.088735')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a199'),
#   'geocode': {'latitude': Decimal128('51.082867')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a19a'),
#   'geocode': {'latitude': Decimal128('51.0806446')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a19c'),
#   'geocode': {'latitude': Decimal128('51.078317')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a19d'),
#   'geocode': {'latitude': Decimal128('51.080669')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a19e'),
#   'geocode': {'latitude': Decimal128('51.080669')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a19f'),
#   'geocode': {'latitude': Decimal128('51.0808513')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1a0'),
#   'geocode': {'latitude': Decimal128('51.078211')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1a1'),
#   'geocode': {'latitude': Decimal128('51.0810699462891')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1a2'),
#   'geocode': {'latitude': Decimal128('51.080624')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1a3'),
#   'geocode': {'latitude': Decimal128('51.083108')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1a4'),
#   'geocode': {'latitude': Decimal128('51.080668')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1a5'),
#   'geocode': {'latitude': Decimal128('51.0782127380371')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1a6'),
#   'geocode': {'latitude': Decimal128('51.079081')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1a7'),
#   'geocode': {'latitude': Decimal128('51.079679')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1a8'),
#   'geocode': {'latitude': Decimal128('51.079679')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1a9'),
#   'geocode': {'latitude': Decimal128('51.079679')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1aa'),
#   'geocode': {'latitude': Decimal128('51.079679')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1ab'),
#   'geocode': {'latitude': Decimal128('51.0776252746582')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1ac'),
#   'geocode': {'latitude': Decimal128('51.076653')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1ad'),
#   'geocode': {'latitude': Decimal128('51.077626')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1ae'),
#   'geocode': {'latitude': Decimal128('51.077626')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1af'),
#   'geocode': {'latitude': Decimal128('51.077626')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1b0'),
#   'geocode': {'latitude': Decimal128('51.087185')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1b1'),
#   'geocode': {'latitude': Decimal128('51.077626')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1b2'),
#   'geocode': {'latitude': Decimal128('51.0776458')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1b3'),
#   'geocode': {'latitude': Decimal128('51.076956')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1b4'),
#   'geocode': {'latitude': Decimal128('51.079081')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1b5'),
#   'geocode': {'latitude': Decimal128('51.078718')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1b6'),
#   'geocode': {'latitude': Decimal128('51.0758056640625')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1b7'),
#   'geocode': {'latitude': Decimal128('51.07879')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1b8'),
#   'geocode': {'latitude': Decimal128('51.078513')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1b9'),
#   'geocode': {'latitude': Decimal128('51.0788531')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1ba'),
#   'geocode': {'latitude': Decimal128('51.078033')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1bb'),
#   'geocode': {'latitude': Decimal128('51.078033')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1bc'),
#   'geocode': {'latitude': Decimal128('51.078033')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1bd'),
#   'geocode': {'latitude': Decimal128('51.078033')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1be'),
#   'geocode': {'latitude': Decimal128('51.09221')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1bf'),
#   'geocode': {'latitude': Decimal128('51.087382')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1c0'),
#   'geocode': {'latitude': Decimal128('51.09221')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1c1'),
#   'geocode': {'latitude': Decimal128('51.07873')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1c2'),
#   'geocode': {'latitude': Decimal128('51.0787391662598')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1c3'),
#   'geocode': {'latitude': Decimal128('51.078515')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1c4'),
#   'geocode': {'latitude': Decimal128('51.0812644958496')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1c5'),
#   'geocode': {'latitude': Decimal128('51.07873')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1c6'),
#   'geocode': {'latitude': Decimal128('51.07873')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1c7'),
#   'geocode': {'latitude': Decimal128('51.0806630002457')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1c8'),
#   'geocode': {'latitude': Decimal128('51.07873')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1c9'),
#   'geocode': {'latitude': Decimal128('51.076647')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1ca'),
#   'geocode': {'latitude': Decimal128('51.076647')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1cb'),
#   'geocode': {'latitude': Decimal128('51.076647')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1cc'),
#   'geocode': {'latitude': Decimal128('51.07856')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1cd'),
#   'geocode': {'latitude': Decimal128('51.088115')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1ce'),
#   'geocode': {'latitude': Decimal128('51.088115')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1cf'),
#   'geocode': {'latitude': Decimal128('51.088115')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1d0'),
#   'geocode': {'latitude': Decimal128('51.088115')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1d1'),
#   'geocode': {'latitude': Decimal128('51.088115')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1d2'),
#   'geocode': {'latitude': Decimal128('51.088115')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1d3'),
#   'geocode': {'latitude': Decimal128('51.0881644')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1d4'),
#   'geocode': {'latitude': Decimal128('51.076413')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1d5'),
#   'geocode': {'latitude': Decimal128('51.077492')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1d6'),
#   'geocode': {'latitude': Decimal128('51.080171')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1d7'),
#   'geocode': {'latitude': Decimal128('51.079039')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1d8'),
#   'geocode': {'latitude': Decimal128('51.076577')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1d9'),
#   'geocode': {'latitude': Decimal128('51.080171')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1da'),
#   'geocode': {'latitude': Decimal128('51.088333')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1db'),
#   'geocode': {'latitude': Decimal128('51.077414')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1dc'),
#   'geocode': {'latitude': Decimal128('51.076577')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1dd'),
#   'geocode': {'latitude': Decimal128('51.090286')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1de'),
#   'geocode': {'latitude': Decimal128('51.089337')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1df'),
#   'geocode': {'latitude': Decimal128('51.078718')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1e0'),
#   'geocode': {'latitude': Decimal128('51.077414')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1e1'),
#   'geocode': {'latitude': Decimal128('51.076896')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1e2'),
#   'geocode': {'latitude': Decimal128('51.078515')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1e3'),
#   'geocode': {'latitude': Decimal128('51.0804496')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1e4'),
#   'geocode': {'latitude': Decimal128('51.078033')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1e5'),
#   'geocode': {'latitude': Decimal128('51.077626')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1e6'),
#   'geocode': {'latitude': Decimal128('51.076956')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1e7'),
#   'geocode': {'latitude': Decimal128('51.077702')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1e8'),
#   'geocode': {'latitude': Decimal128('51.074167')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1e9'),
#   'geocode': {'latitude': Decimal128('51.078197')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1ea'),
#   'geocode': {'latitude': Decimal128('51.091129')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1eb'),
#   'geocode': {'latitude': Decimal128('51.078197')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1ec'),
#   'geocode': {'latitude': Decimal128('51.078197')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1ed'),
#   'geocode': {'latitude': Decimal128('51.078197')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1ee'),
#   'geocode': {'latitude': Decimal128('51.0833323')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1ef'),
#   'geocode': {'latitude': Decimal128('51.078197')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1f0'),
#   'geocode': {'latitude': Decimal128('51.078197')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1f2'),
#   'geocode': {'latitude': Decimal128('51.078197')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1f3'),
#   'geocode': {'latitude': Decimal128('51.078885')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1f4'),
#   'geocode': {'latitude': Decimal128('51.082381')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1f5'),
#   'geocode': {'latitude': Decimal128('51.079192')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1f6'),
#   'geocode': {'latitude': Decimal128('51.07623')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1f7'),
#   'geocode': {'latitude': Decimal128('51.078068')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1f8'),
#   'geocode': {'latitude': Decimal128('51.07623')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1f9'),
#   'geocode': {'latitude': Decimal128('51.082871')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1fa'),
#   'geocode': {'latitude': Decimal128('51.081154')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1fb'),
#   'geocode': {'latitude': Decimal128('51.078197')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1fc'),
#   'geocode': {'latitude': Decimal128('51.075403')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1fd'),
#   'geocode': {'latitude': Decimal128('51.078874')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1fe'),
#   'geocode': {'latitude': Decimal128('51.085001')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a1ff'),
#   'geocode': {'latitude': Decimal128('51.085038')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a200'),
#   'geocode': {'latitude': Decimal128('51.085038')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a201'),
#   'geocode': {'latitude': Decimal128('51.08129')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a202'),
#   'geocode': {'latitude': Decimal128('51.081291')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a203'),
#   'geocode': {'latitude': Decimal128('51.077243')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a204'),
#   'geocode': {'latitude': Decimal128('51.085038')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a205'),
#   'geocode': {'latitude': Decimal128('51.080533')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a206'),
#   'geocode': {'latitude': Decimal128('51.087034')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a207'),
#   'geocode': {'latitude': Decimal128('51.087034')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a208'),
#   'geocode': {'latitude': Decimal128('51.088893')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a209'),
#   'geocode': {'latitude': Decimal128('51.081291')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a20a'),
#   'geocode': {'latitude': Decimal128('51.088124')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a20b'),
#   'geocode': {'latitude': Decimal128('51.086485')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a20c'),
#   'geocode': {'latitude': Decimal128('51.085365')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a20d'),
#   'geocode': {'latitude': Decimal128('51.085872')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a20f'),
#   'geocode': {'latitude': Decimal128('51.088125')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a210'),
#   'geocode': {'latitude': Decimal128('51.080302')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a211'),
#   'geocode': {'latitude': Decimal128('51.0819')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a212'),
#   'geocode': {'latitude': Decimal128('51.082331')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a214'),
#   'geocode': {'latitude': Decimal128('51.077289')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a215'),
#   'geocode': {'latitude': Decimal128('51.090168')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a216'),
#   'geocode': {'latitude': Decimal128('51.08885')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a217'),
#   'geocode': {'latitude': Decimal128('51.090195')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a218'),
#   'geocode': {'latitude': Decimal128('51.087034')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a219'),
#   'geocode': {'latitude': Decimal128('51.088806')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a21a'),
#   'geocode': {'latitude': Decimal128('51.082332')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a21b'),
#   'geocode': {'latitude': Decimal128('51.081795')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a21c'),
#   'geocode': {'latitude': Decimal128('51.0769439')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a21d'),
#   'geocode': {'latitude': Decimal128('51.077737')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a21e'),
#   'geocode': {'latitude': Decimal128('51.07555')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a21f'),
#   'geocode': {'latitude': Decimal128('51.0932246')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a220'),
#   'geocode': {'latitude': Decimal128('51.08186')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a221'),
#   'geocode': {'latitude': Decimal128('51.085552')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a222'),
#   'geocode': {'latitude': Decimal128('51.085553')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a223'),
#   'geocode': {'latitude': Decimal128('51.0817527770996')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a224'),
#   'geocode': {'latitude': Decimal128('51.082374')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a225'),
#   'geocode': {'latitude': Decimal128('51.082374')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a227'),
#   'geocode': {'latitude': Decimal128('51.082374')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a228'),
#   'geocode': {'latitude': Decimal128('51.076949')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a229'),
#   'geocode': {'latitude': Decimal128('51.083812713623')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a22b'),
#   'geocode': {'latitude': Decimal128('51.08382')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a22c'),
#   'geocode': {'latitude': Decimal128('51.0751419067383')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a22d'),
#   'geocode': {'latitude': Decimal128('51.095177')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a22e'),
#   'geocode': {'latitude': Decimal128('51.095177')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a22f'),
#   'geocode': {'latitude': Decimal128('51.07507')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a230'),
#   'geocode': {'latitude': Decimal128('51.095177')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a231'),
#   'geocode': {'latitude': Decimal128('51.078911')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a232'),
#   'geocode': {'latitude': Decimal128('51.095177')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a234'),
#   'geocode': {'latitude': Decimal128('51.08538')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a235'),
#   'geocode': {'latitude': Decimal128('51.085755')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a236'),
#   'geocode': {'latitude': Decimal128('51.082833')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a23c'),
#   'geocode': {'latitude': Decimal128('51.079404')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a23e'),
#   'geocode': {'latitude': Decimal128('51.087373')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a240'),
#   'geocode': {'latitude': Decimal128('51.080017')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a242'),
#   'geocode': {'latitude': Decimal128('51.0813407897949')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a243'),
#   'geocode': {'latitude': Decimal128('51.076559')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a244'),
#   'geocode': {'latitude': Decimal128('51.082434')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a245'),
#   'geocode': {'latitude': Decimal128('51.087373')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a248'),
#   'geocode': {'latitude': Decimal128('51.084325')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a249'),
#   'geocode': {'latitude': Decimal128('51.081358')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a24a'),
#   'geocode': {'latitude': Decimal128('51.084325')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a24b'),
#   'geocode': {'latitude': Decimal128('51.090416')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a24c'),
#   'geocode': {'latitude': Decimal128('51.090416')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a24d'),
#   'geocode': {'latitude': Decimal128('51.085565')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a24f'),
#   'geocode': {'latitude': Decimal128('51.335713')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a250'),
#   'geocode': {'latitude': Decimal128('51.336816')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a251'),
#   'geocode': {'latitude': Decimal128('51.3344841003418')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a252'),
#   'geocode': {'latitude': Decimal128('51.338414')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a253'),
#   'geocode': {'latitude': Decimal128('51.335713')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a254'),
#   'geocode': {'latitude': Decimal128('51.076715')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a255'),
#   'geocode': {'latitude': Decimal128('51.085871')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a256'),
#   'geocode': {'latitude': Decimal128('51.3322105407715')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a257'),
#   'geocode': {'latitude': Decimal128('51.338414')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a258'),
#   'geocode': {'latitude': Decimal128('51.332221')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a259'),
#   'geocode': {'latitude': Decimal128('51.332221')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a25b'),
#   'geocode': {'latitude': Decimal128('51.33222')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a25c'),
#   'geocode': {'latitude': Decimal128('51.33222')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a25d'),
#   'geocode': {'latitude': Decimal128('51.33222')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a25e'),
#   'geocode': {'latitude': Decimal128('51.332221')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a25f'),
#   'geocode': {'latitude': Decimal128('51.332221')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a260'),
#   'geocode': {'latitude': Decimal128('51.332221')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a261'),
#   'geocode': {'latitude': Decimal128('51.332221')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a262'),
#   'geocode': {'latitude': Decimal128('51.332221')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a263'),
#   'geocode': {'latitude': Decimal128('51.332221')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a264'),
#   'geocode': {'latitude': Decimal128('51.332221')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a265'),
#   'geocode': {'latitude': Decimal128('51.332221')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a266'),
#   'geocode': {'latitude': Decimal128('51.332221')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a267'),
#   'geocode': {'latitude': Decimal128('51.332221')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a268'),
#   'geocode': {'latitude': Decimal128('51.3322219848633')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a269'),
#   'geocode': {'latitude': Decimal128('51.092175')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a26a'),
#   'geocode': {'latitude': Decimal128('51.3322219848633')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a26c'),
#   'geocode': {'latitude': Decimal128('51.087041')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a26d'),
#   'geocode': {'latitude': Decimal128('51.3351135253906')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a26e'),
#   'geocode': {'latitude': Decimal128('51.331022')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a26f'),
#   'geocode': {'latitude': Decimal128('51.332386')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a270'),
#   'geocode': {'latitude': Decimal128('51.349914')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a271'),
#   'geocode': {'latitude': Decimal128('51.332386')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a273'),
#   'geocode': {'latitude': Decimal128('51.332386')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a274'),
#   'geocode': {'latitude': Decimal128('51.332386')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a275'),
#   'geocode': {'latitude': Decimal128('51.332386')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a276'),
#   'geocode': {'latitude': Decimal128('51.343133')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a277'),
#   'geocode': {'latitude': Decimal128('51.343133')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a278'),
#   'geocode': {'latitude': Decimal128('51.332495')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a279'),
#   'geocode': {'latitude': Decimal128('51.074546')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a27a'),
#   'geocode': {'latitude': Decimal128('51.335185')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a27b'),
#   'geocode': {'latitude': Decimal128('51.335185')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a27c'),
#   'geocode': {'latitude': Decimal128('51.33237')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a27e'),
#   'geocode': {'latitude': Decimal128('51.351811')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a27f'),
#   'geocode': {'latitude': Decimal128('51.33336')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a280'),
#   'geocode': {'latitude': Decimal128('51.3330688476563')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a282'),
#   'geocode': {'latitude': Decimal128('51.3322715759277')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a284'),
#   'geocode': {'latitude': Decimal128('51.334809')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a285'),
#   'geocode': {'latitude': Decimal128('51.33308')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a286'),
#   'geocode': {'latitude': Decimal128('51.33308')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a287'),
#   'geocode': {'latitude': Decimal128('51.3332063')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a288'),
#   'geocode': {'latitude': Decimal128('51.077345')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a289'),
#   'geocode': {'latitude': Decimal128('51.333009')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a28a'),
#   'geocode': {'latitude': Decimal128('51.333009')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a28b'),
#   'geocode': {'latitude': Decimal128('51.330413')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a28c'),
#   'geocode': {'latitude': Decimal128('51.33308')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a28d'),
#   'geocode': {'latitude': Decimal128('51.330413')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a28e'),
#   'geocode': {'latitude': Decimal128('51.333009')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a28f'),
#   'geocode': {'latitude': Decimal128('51.330413')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a290'),
#   'geocode': {'latitude': Decimal128('51.330413')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a292'),
#   'geocode': {'latitude': Decimal128('51.333152')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a293'),
#   'geocode': {'latitude': Decimal128('51.333009')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a294'),
#   'geocode': {'latitude': Decimal128('51.333918')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a295'),
#   'geocode': {'latitude': Decimal128('51.333009')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a296'),
#   'geocode': {'latitude': Decimal128('51.352901')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a297'),
#   'geocode': {'latitude': Decimal128('51.333009')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a298'),
#   'geocode': {'latitude': Decimal128('51.0737868')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a29a'),
#   'geocode': {'latitude': Decimal128('51.333009')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a29b'),
#   'geocode': {'latitude': Decimal128('51.3310761')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a29c'),
#   'geocode': {'latitude': Decimal128('51.332515')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a29d'),
#   'geocode': {'latitude': Decimal128('51.086577')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a29e'),
#   'geocode': {'latitude': Decimal128('51.33875')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a29f'),
#   'geocode': {'latitude': Decimal128('51.33308')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2a0'),
#   'geocode': {'latitude': Decimal128('51.33237')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2a1'),
#   'geocode': {'latitude': Decimal128('51.3341272')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2a2'),
#   'geocode': {'latitude': Decimal128('51.332812')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2a3'),
#   'geocode': {'latitude': Decimal128('51.332812')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2a4'),
#   'geocode': {'latitude': Decimal128('51.332812')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2a5'),
#   'geocode': {'latitude': Decimal128('51.332812')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2a6'),
#   'geocode': {'latitude': Decimal128('51.332812')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2a7'),
#   'geocode': {'latitude': Decimal128('51.332812')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2a8'),
#   'geocode': {'latitude': Decimal128('51.3338775634766')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2a9'),
#   'geocode': {'latitude': Decimal128('51.332812')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2aa'),
#   'geocode': {'latitude': Decimal128('51.331827')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2ab'),
#   'geocode': {'latitude': Decimal128('51.332812')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2ac'),
#   'geocode': {'latitude': Decimal128('51.331827')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2ad'),
#   'geocode': {'latitude': Decimal128('51.332812')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2ae'),
#   'geocode': {'latitude': Decimal128('51.332812')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2af'),
#   'geocode': {'latitude': Decimal128('51.331827')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2b0'),
#   'geocode': {'latitude': Decimal128('51.331827')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2b1'),
#   'geocode': {'latitude': Decimal128('51.33442')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2b2'),
#   'geocode': {'latitude': Decimal128('51.3348208')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2b3'),
#   'geocode': {'latitude': Decimal128('51.3319')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2b4'),
#   'geocode': {'latitude': Decimal128('51.33442')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2b5'),
#   'geocode': {'latitude': Decimal128('51.3328557')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2b6'),
#   'geocode': {'latitude': Decimal128('51.3348734')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2b8'),
#   'geocode': {'latitude': Decimal128('51.331827')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2b9'),
#   'geocode': {'latitude': Decimal128('51.333774')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2ba'),
#   'geocode': {'latitude': Decimal128('51.3332961')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2bb'),
#   'geocode': {'latitude': Decimal128('51.337357')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2bc'),
#   'geocode': {'latitude': Decimal128('51.330249')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2bd'),
#   'geocode': {'latitude': Decimal128('51.335788')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2be'),
#   'geocode': {'latitude': Decimal128('51.33811')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2bf'),
#   'geocode': {'latitude': Decimal128('51.340005')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2c0'),
#   'geocode': {'latitude': Decimal128('51.330249')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2c1'),
#   'geocode': {'latitude': Decimal128('51.333159')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2c2'),
#   'geocode': {'latitude': Decimal128('51.3373565673828')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2c3'),
#   'geocode': {'latitude': Decimal128('51.333075')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2c4'),
#   'geocode': {'latitude': Decimal128('51.333159')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2c5'),
#   'geocode': {'latitude': Decimal128('51.333159')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2c6'),
#   'geocode': {'latitude': Decimal128('51.330249')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2c7'),
#   'geocode': {'latitude': Decimal128('51.33542')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2c8'),
#   'geocode': {'latitude': Decimal128('51.333159')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2c9'),
#   'geocode': {'latitude': Decimal128('51.33542')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2ca'),
#   'geocode': {'latitude': Decimal128('51.33542')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2cb'),
#   'geocode': {'latitude': Decimal128('51.333174')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2cc'),
#   'geocode': {'latitude': Decimal128('51.334698')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2cd'),
#   'geocode': {'latitude': Decimal128('51.334698')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2ce'),
#   'geocode': {'latitude': Decimal128('51.33542')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2cf'),
#   'geocode': {'latitude': Decimal128('51.334698')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2d0'),
#   'geocode': {'latitude': Decimal128('51.33407')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a2d1'),
# ...
#   'geocode': {'latitude': Decimal128('51.07912')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a464'),
#   'geocode': {'latitude': Decimal128('51.07912')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a468'),
#   'geocode': {'latitude': Decimal128('51.07912')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a469'),
#   'geocode': {'latitude': Decimal128('51.087802')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a46b'),
#   'geocode': {'latitude': Decimal128('51.07912')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a46c'),
#   'geocode': {'latitude': Decimal128('51.331076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a473'),
#   'geocode': {'latitude': Decimal128('51.33806')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a474'),
#   'geocode': {'latitude': Decimal128('51.33273')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a47a'),
#   'geocode': {'latitude': Decimal128('51.3378982543945')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a47d'),
#   'geocode': {'latitude': Decimal128('51.0876528')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a47e'),
#   'geocode': {'latitude': Decimal128('51.083039')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a480'),
#   'geocode': {'latitude': Decimal128('51.335832')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a482'),
#   'geocode': {'latitude': Decimal128('51.087952')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a483'),
#   'geocode': {'latitude': Decimal128('51.087952')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a484'),
#   'geocode': {'latitude': Decimal128('51.087952')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a485'),
#   'geocode': {'latitude': Decimal128('51.094664')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a48a'),
#   'geocode': {'latitude': Decimal128('51.0877039')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a48b'),
#   'geocode': {'latitude': Decimal128('51.087712')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a48c'),
#   'geocode': {'latitude': Decimal128('51.087712')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a490'),
#   'geocode': {'latitude': Decimal128('51.087712')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a496'),
#   'geocode': {'latitude': Decimal128('51.336627')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a497'),
#   'geocode': {'latitude': Decimal128('51.0880646')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a49a'),
#   'geocode': {'latitude': Decimal128('51.0939979553223')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a49c'),
#   'geocode': {'latitude': Decimal128('50.923027')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a49e'),
#   'geocode': {'latitude': Decimal128('50.923027')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4a0'),
#   'geocode': {'latitude': Decimal128('51.363477')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4a3'),
#   'geocode': {'latitude': Decimal128('50.923027')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4a4'),
#   'geocode': {'latitude': Decimal128('51.087712')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4a5'),
#   'geocode': {'latitude': Decimal128('51.363477')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4a6'),
#   'geocode': {'latitude': Decimal128('51.361719')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4ad'),
#   'geocode': {'latitude': Decimal128('51.0918312072754')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4b0'),
#   'geocode': {'latitude': Decimal128('51.327274')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4b1'),
#   'geocode': {'latitude': Decimal128('51.0950376')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4b3'),
#   'geocode': {'latitude': Decimal128('51.327274')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4b4'),
#   'geocode': {'latitude': Decimal128('51.087129')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4b5'),
#   'geocode': {'latitude': Decimal128('51.087943')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4b6'),
#   'geocode': {'latitude': Decimal128('51.3613628')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4b7'),
#   'geocode': {'latitude': Decimal128('51.086717')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4b8'),
#   'geocode': {'latitude': Decimal128('51.087943')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4b9'),
#   'geocode': {'latitude': Decimal128('51.3409817')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4ba'),
#   'geocode': {'latitude': Decimal128('51.095079')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4bc'),
#   'geocode': {'latitude': Decimal128('50.915115')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4bd'),
#   'geocode': {'latitude': Decimal128('51.337775')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4be'),
#   'geocode': {'latitude': Decimal128('51.337822')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4bf'),
#   'geocode': {'latitude': Decimal128('51.0793075561523')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4c0'),
#   'geocode': {'latitude': Decimal128('51.337822')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4c1'),
#   'geocode': {'latitude': Decimal128('51.337822')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4c2'),
#   'geocode': {'latitude': Decimal128('51.337822')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4c4'),
#   'geocode': {'latitude': Decimal128('51.3361178')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4c6'),
#   'geocode': {'latitude': Decimal128('50.9133071899414')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4c7'),
#   'geocode': {'latitude': Decimal128('51.337043')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4c8'),
#   'geocode': {'latitude': Decimal128('51.337043')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4ca'),
#   'geocode': {'latitude': Decimal128('51.337043')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4cc'),
#   'geocode': {'latitude': Decimal128('51.0879795')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4cd'),
#   'geocode': {'latitude': Decimal128('51.090854')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4ce'),
#   'geocode': {'latitude': Decimal128('51.087175')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4cf'),
#   'geocode': {'latitude': Decimal128('51.0880352906826')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4d0'),
#   'geocode': {'latitude': Decimal128('51.087931')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4d1'),
#   'geocode': {'latitude': Decimal128('51.087175')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4d2'),
#   'geocode': {'latitude': Decimal128('51.087931')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4d3'),
#   'geocode': {'latitude': Decimal128('51.087931')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4d4'),
#   'geocode': {'latitude': Decimal128('51.088015130205')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4d5'),
#   'geocode': {'latitude': Decimal128('51.362908')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4d6'),
#   'geocode': {'latitude': Decimal128('51.088349')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4d7'),
#   'geocode': {'latitude': Decimal128('51.33662')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4d8'),
#   'geocode': {'latitude': Decimal128('51.08626')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4d9'),
#   'geocode': {'latitude': Decimal128('51.0880283897589')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4da'),
#   'geocode': {'latitude': Decimal128('51.34523')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4db'),
#   'geocode': {'latitude': Decimal128('51.084261')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4dc'),
#   'geocode': {'latitude': Decimal128('51.33662')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4dd'),
#   'geocode': {'latitude': Decimal128('51.084261')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4de'),
#   'geocode': {'latitude': Decimal128('51.093315')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4e1'),
#   'geocode': {'latitude': Decimal128('51.338829')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4e2'),
#   'geocode': {'latitude': Decimal128('51.338829')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4e3'),
#   'geocode': {'latitude': Decimal128('51.338829')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4e4'),
#   'geocode': {'latitude': Decimal128('51.366877')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4e5'),
#   'geocode': {'latitude': Decimal128('51.366877')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4e6'),
#   'geocode': {'latitude': Decimal128('51.3668785095215')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4e7'),
#   'geocode': {'latitude': Decimal128('51.089168')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4e9'),
#   'geocode': {'latitude': Decimal128('51.345305')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4eb'),
#   'geocode': {'latitude': Decimal128('51.083198')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4ec'),
#   'geocode': {'latitude': Decimal128('51.368648')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4ed'),
#   'geocode': {'latitude': Decimal128('51.087407')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4ee'),
#   'geocode': {'latitude': Decimal128('51.331795')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4ef'),
#   'geocode': {'latitude': Decimal128('51.113576')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4f0'),
#   'geocode': {'latitude': Decimal128('51.348733')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4f1'),
#   'geocode': {'latitude': Decimal128('51.348733')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4f2'),
#   'geocode': {'latitude': Decimal128('51.3317947387695')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4f3'),
#   'geocode': {'latitude': Decimal128('51.371076')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4f4'),
#   'geocode': {'latitude': Decimal128('51.3635864257812')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4f5'),
#   'geocode': {'latitude': Decimal128('51.091441')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4f6'),
#   'geocode': {'latitude': Decimal128('51.360875')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4f7'),
#   'geocode': {'latitude': Decimal128('51.112388')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4f8'),
#   'geocode': {'latitude': Decimal128('51.381812')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4fa'),
#   'geocode': {'latitude': Decimal128('51.3663')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4fb'),
#   'geocode': {'latitude': Decimal128('51.091013')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4fc'),
#   'geocode': {'latitude': Decimal128('50.9134254455566')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4fd'),
#   'geocode': {'latitude': Decimal128('51.087434')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4fe'),
#   'geocode': {'latitude': Decimal128('51.107275')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a4ff'),
#   'geocode': {'latitude': Decimal128('51.346842')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a501'),
#   'geocode': {'latitude': Decimal128('51.1150651')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a502'),
#   'geocode': {'latitude': Decimal128('51.0722274780273')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a503'),
#   'geocode': {'latitude': Decimal128('51.1150651')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a504'),
#   'geocode': {'latitude': Decimal128('51.072229')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a505'),
#   'geocode': {'latitude': Decimal128('51.356504')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a506'),
#   'geocode': {'latitude': Decimal128('51.335425')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a508'),
#   'geocode': {'latitude': Decimal128('51.072229')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a50a'),
#   'geocode': {'latitude': Decimal128('51.11213')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a50b'),
#   'geocode': {'latitude': Decimal128('51.35691')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a50c'),
#   'geocode': {'latitude': Decimal128('51.343189')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a50d'),
#   'geocode': {'latitude': Decimal128('51.115816')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a50e'),
#   'geocode': {'latitude': Decimal128('51.359859')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a50f'),
#   'geocode': {'latitude': Decimal128('50.928769')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a510'),
#   'geocode': {'latitude': Decimal128('51.090777')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a511'),
#   'geocode': {'latitude': Decimal128('51.110991')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a513'),
#   'geocode': {'latitude': Decimal128('50.928769')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a514'),
#   'geocode': {'latitude': Decimal128('51.115817')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a515'),
#   'geocode': {'latitude': Decimal128('51.092698')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a516'),
#   'geocode': {'latitude': Decimal128('51.110991')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a517'),
#   'geocode': {'latitude': Decimal128('51.115817')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a518'),
#   'geocode': {'latitude': Decimal128('51.115817')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a519'),
#   'geocode': {'latitude': Decimal128('51.110454')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a51a'),
#   'geocode': {'latitude': Decimal128('51.092698')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a51c'),
#   'geocode': {'latitude': Decimal128('51.3518028259277')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a51d'),
#   'geocode': {'latitude': Decimal128('51.1165313720703')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a51e'),
#   'geocode': {'latitude': Decimal128('51.38035')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a51f'),
#   'geocode': {'latitude': Decimal128('51.356199')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a520'),
#   'geocode': {'latitude': Decimal128('51.343189')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a521'),
#   'geocode': {'latitude': Decimal128('51.116532')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a522'),
#   'geocode': {'latitude': Decimal128('51.112412')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a523'),
#   'geocode': {'latitude': Decimal128('51.112412')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a524'),
#   'geocode': {'latitude': Decimal128('51.0726696')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a525'),
#   'geocode': {'latitude': Decimal128('51.360944')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a526'),
#   'geocode': {'latitude': Decimal128('51.3485244')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a527'),
#   'geocode': {'latitude': Decimal128('51.366986')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a528'),
#   'geocode': {'latitude': Decimal128('51.112412')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a529'),
#   'geocode': {'latitude': Decimal128('51.381088')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a52a'),
#   'geocode': {'latitude': Decimal128('51.122522')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a52b'),
#   'geocode': {'latitude': Decimal128('51.3429296')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a52c'),
#   'geocode': {'latitude': Decimal128('51.072477')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a52d'),
#   'geocode': {'latitude': Decimal128('51.088298')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a52f'),
#   'geocode': {'latitude': Decimal128('51.088298')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a530'),
#   'geocode': {'latitude': Decimal128('51.3539278')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a531'),
#   'geocode': {'latitude': Decimal128('51.354229')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a532'),
#   'geocode': {'latitude': Decimal128('51.343344')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a535'),
#   'geocode': {'latitude': Decimal128('51.3699684143066')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a536'),
#   'geocode': {'latitude': Decimal128('51.369967')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a537'),
#   'geocode': {'latitude': Decimal128('51.3743057250977')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a538'),
#   'geocode': {'latitude': Decimal128('51.374308')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a539'),
#   'geocode': {'latitude': Decimal128('51.369967')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a53a'),
#   'geocode': {'latitude': Decimal128('51.088897')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a53b'),
#   'geocode': {'latitude': Decimal128('51.3743057250977')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a53c'),
#   'geocode': {'latitude': Decimal128('51.377667')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a53d'),
#   'geocode': {'latitude': Decimal128('51.377667')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a53e'),
#   'geocode': {'latitude': Decimal128('51.356848')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a53f'),
#   'geocode': {'latitude': Decimal128('51.352702')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a540'),
#   'geocode': {'latitude': Decimal128('51.367482')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a541'),
#   'geocode': {'latitude': Decimal128('51.343957')}},
#  {'_id': ObjectId('66ff347343bdc9d6fcc1a542'),
#   'geocode': {'latitude': Decimal128('51.364585')}},
#  ...]
